-- %%
GRANT USE CATALOG ON CATALOG agentbricks TO `0f34bfb0-e7df-432e-857a-143a1601e7b9`;
GRANT USE SCHEMA ON SCHEMA agentbricks.volumes TO `0f34bfb0-e7df-432e-857a-143a1601e7b9`;
GRANT READ VOLUME ON VOLUME agentbricks.volumes.pictures TO `0f34bfb0-e7df-432e-857a-143a1601e7b9`;
