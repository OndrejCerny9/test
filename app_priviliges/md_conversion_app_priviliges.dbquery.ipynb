-- %%
GRANT USE CATALOG ON CATALOG agentbricks
TO `1a05c573-ebd0-4058-919b-21fc18288fc5`;

GRANT USE SCHEMA ON SCHEMA agentbricks.volumes
TO `1a05c573-ebd0-4058-919b-21fc18288fc5`;

GRANT READ VOLUME, WRITE VOLUME ON VOLUME agentbricks.volumes.agent_reports
TO `1a05c573-ebd0-4058-919b-21fc18288fc5`;

GRANT READ VOLUME ON VOLUME agentbricks.volumes.pictures
TO `1a05c573-ebd0-4058-919b-21fc18288fc5`;
