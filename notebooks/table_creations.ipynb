-- %% [markdown]
-- ### report_picture_metadata

-- %%
CREATE TABLE IF NOT EXISTS agentbricks.sector_data_bronze.report_picture_metadata (
  chart_id STRING,
  sector STRING,
  chart_title STRING,
  chart_description STRING,
  suggested_commentary STRING,
  image_filename STRING,
  image_url STRING,
  markdown_reference STRING,
  source_table STRING,
  created_at TIMESTAMP,
  image_path STRING,
  columns_used STRING
);

-- %%
ALTER TABLE agentbricks.sector_data_bronze.report_picture_metadata
ADD COLUMNS (
    image_path STRING,
    columns_used STRING
);
